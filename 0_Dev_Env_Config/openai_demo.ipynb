# %% [markdown]
# # OpenAI Demo Notebook

# %%
# Step 1: Install Dependencies
from dotenv import load_dotenv
from openai import OpenAI

# %%
# Step 2: Load API key from .env file
load_dotenv()
client = OpenAI()

# %%
# Step 3: Ask OpenAI a question
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": "Who are you?"}]
)

# Step 3: Show the answer
print(response.choices[0].message.content)
# Out:
# I am an AI digital assistant here to help you with any questions or tasks you may have. How can I assist you today?
